# %% [markdown]
# <a href="https://colab.research.google.com/github/valenja9/Python_11_14_II_9_2021/blob/main/Python_11_14_II_10_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#
jmeno = "Petr"
vek = 5
slovnik = {"jmeno": "Petr", "prijmeni": "Novak"}

# %%
slovnik = {"jmeno": "Petr", "prijmeni": "Novak"}
slovnik["adresa"] = "Pk.22"

# %%
"a" + "b"
# Out:
# 'ab'

# %%
print("Ahoj", "Jak se vede?")
# Out:
# Ahoj Jak se vede?

# %%
print("Ahoj", "Jak se vede?", sep='\n')
# Out:
# Ahoj
# Jak se vede?

# %%
jmeno == "Jakub"

# %%
jmeno != "Jakub"

# %%
slovo in ["exit", "Exit", "EXIT"]

# %%
jmeno = "Jakub"
prijmeni = "Novak"
if jmeno.isalpha() and prijmeni.isalpha():
  print("Oboje je pravda.")
# Out:
# Oboje je pravda.

# %%
jmeno = "Jakub"
prijmeni = ""
if jmeno or prijmeno:
  print("Aspon jedno")
# Out:
# Aspon jedno

# %%
slovo = "exit"
while slovo in ["exit", "Exit", "EXIT"]:
  print("Ano")
# Out:
# Streaming output truncated to the last 5000 lines.
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# Ano
# ...

# %%
l = []
while  l: #ptam se na to jestli je neco uvnitr listu

# %%
for jmeno in list_jmen:
  if jmeno[0] == "K":
    print(jmeno)
  else:
    print("Nic")
# Out:
# Nic
# Kamil
# Nic

# %%
oddelovac = "-" * 80
print(oddelovac)
# Out:
# --------------------------------------------------------------------------------

# %%
list_jmen = ["Petr", "Kamil", "Jakub"]

# %%
#pro vlozeni do listu
list_jmen.append("neco")

# %%
list_jmen[3]
# Out:
# 'neco'

# %%
list_jmen.count("neco")
# Out:
# 1

# %%
list_jmen.insert(0, "dej to na nulu")

# %%
print(list_jmen)
# Out:
# ['dej to na nulu', 'Petr', 'Kamil', 'Jakub', 'neco']

# %%
text = "Ahoj"

# %%
text.lower()
# Out:
# 'ahoj'

# %%
text.upper()
# Out:
# 'AHOJ'

# %%
text.title()
# Out:
# 'Ahoj'

# %%
text.split()
# Out:
# ['Ahoj']

# %%
"+".join(["Jakub", "Petr", "Kamil", "Honza"])
# Out:
# 'Jakub+Petr+Kamil+Honza'

# %%
while True:
  zadani = input("Napis co chces zadat nebo dej exit: ").lower()
  if zadani == "exit":
    break
  else:
    print(zadani)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     624         """
# --> 625         parts = [self.recv(flags, copy=copy, track=track)]
#     626         # have first part already, only loop while more to receive
#
# ...

# %%
#funkce nema parametry a pouziva x,y z predchozi definice
x = 5
y = 6
def funkce():
  print(x + y)

funkce()
# Out:
# 11

# %%
#Funkce ma parametry a nic nevraci
def funkce(x, y):
  print(x + y)
funkce(40,50)
# Out:
# 90

# %%
#chci aby vracela
def funkce(x, y):
  return x + y
vysledek = funkce(40,50)

# %%
#Vytvor program, ktery te uvita podle jmena.
oddelovac = "-" * 80
print("Tato hra prave zacina.")
jmeno = input("Zadej sve jmeno.")
print(oddelovac,f"Ahoj {jmeno}, vytej v teto hre." , oddelovac,sep='\n')
# Out:
# Tato hra prave zacina.
# Zadej sve jmeno.Jakub
# --------------------------------------------------------------------------------
# Ahoj Jakub, vytej v teto hre.
# --------------------------------------------------------------------------------

# %%
#Vytvor program na random generovani slov
import random
moznosti = ["banan", "jablko", "hruska", "mandarinka", "karamel"]
slovo = random.choice(moznosti)
print(slovo)
# Out:
# mandarinka

# %%
#udelej funkci, ktera vraci slovo.
moznosti = ["banan", "jablko", "hruska", "mandarinka", "karamel"]
def generuj_slovo(moznosti):
  slovo = random.choice(moznosti)
  return slovo

# %%
generuj_slovo(moznosti)
# Out:
# 'banan'

# %%
#Program vezme slovo a udela tajenku.(vytvori list_ktery bude mit stejny pocet _ jako pismen)
tajenka = len(slovo) * ["_"]
print(tajenka)
# Out:
# ['_', '_', '_', '_', '_', '_', '_', '_', '_', '_']

# %%
def vytvor_tajenku(slovo):
  return len(slovo) * ["_"]
  
tajenka = vytvor_tajenku(slovo)
